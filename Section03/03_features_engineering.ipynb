# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Feature engineering").getOrCreate()
# Out:
# 26/06/16 14:25:21 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
data = spark.read.csv("data/housing.csv", header=True, inferSchema=True)

data.printSchema()
# Out:
# root
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- housing_median_age: double (nullable = true)
#  |-- total_rooms: double (nullable = true)
#  |-- total_bedrooms: double (nullable = true)
#  |-- population: double (nullable = true)
#  |-- households: double (nullable = true)
#  |-- median_income: double (nullable = true)
#  |-- median_house_value: double (nullable = true)
#  |-- ocean_proximity: string (nullable = true)

# %%
filtered_data = data.na.drop(subset=['total_bedrooms'])
filtered_data.count()
# Out:
# 20433

# %%
train_data, test_data = filtered_data.randomSplit([0.8, 0.2], seed=42)
print("Train size: ", train_data.count())
print("Test size: ", test_data.count())
test_data.show()
# Out:
# Train size:  16395
# Test size:  4038
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# |   -124.3|   41.84|              17.0|     2677.0|         531.0|    1244.0|     456.0|       3.0313|          103600.0|     NEAR OCEAN|
# |  -124.23|   40.54|              52.0|     2694.0|         453.0|    1152.0|     435.0|       3.0806|          106700.0|     NEAR OCEAN|
# |  -124.23|   41.75|              11.0|     3159.0|         616.0|    1343.0|     479.0|       2.4805|           73200.0|     NEAR OCEAN|
# |  -124.19|   40.73|              21.0|     5694.0|        1056.0|    2907.0|     972.0|       3.5363|           90100.0|     NEAR OCEAN|
# |  -124.18|   40.78|              34.0|     1592.0|         364.0|     950.0|     317.0|       2.1607|           67000.0|     NEAR OCEAN|
# |  -124.17|   40.62|              32.0|     1595.0|         309.0|     706.0|     277.0|       2.8958|           86400.0|     NEAR OCEAN|
# |  -124.17|   40.79|              43.0|     2285.0|         479.0|    1169.0|     482.0|       1.9688|           70500.0|     NEAR OCEAN|
# |  -124.16|    40.6|              39.0|     1322.0|         283.0|     642.0|     292.0|       2.4519|           85100.0|     NEAR OCEAN|
# |  -124.16|    40.8|              52.0|     2416.0|         618.0|    1150.0|     571.0|       1.7308|           80500.0|     NEAR OCEAN|
# |  -124.16|   40.95|              20.0|     1075.0|         214.0|     529.0|     196.0|       3.1406|           96000.0|     NEAR OCEAN|
# |  -124.16|   41.02|              23.0|     1672.0|         385.0|    1060.0|     390.0|       2.1726|           75500.0|     NEAR OCEAN|
# |  -124.16|   41.92|              19.0|     1668.0|         324.0|     841.0|     283.0|       2.1336|           75000.0|     NEAR OCEAN|
# |  -124.15|   40.76|              24.0|     2858.0|         511.0|    1388.0|     512.0|        3.375|          100600.0|     NEAR OCEAN|
# |  -124.15|    40.8|              47.0|     1486.0|         335.0|     765.0|     329.0|        1.755|           74100.0|     NEAR OCEAN|
# |  -124.14|   40.59|              22.0|     1665.0|         405.0|     826.0|     382.0|       1.5625|           66800.0|     NEAR OCEAN|
# |  -124.14|    40.8|              32.0|     1373.0|         312.0|     872.0|     306.0|          2.5|           72600.0|     NEAR OCEAN|
# |  -124.11|   40.57|              33.0|     1348.0|         234.0|     573.0|     236.0|       2.4896|           74100.0|      <1H OCEAN|
# |  -124.08|   40.86|              18.0|     1287.0|         484.0|     805.0|     502.0|       1.1157|          150000.0|     NEAR OCEAN|
# |  -124.05|   40.85|              31.0|     2414.0|         428.0|    1005.0|     401.0|       3.5156|          143000.0|     NEAR OCEAN|
# |  -124.02|    40.8|              22.0|     2588.0|         435.0|    1198.0|     442.0|       3.9792|          133900.0|      <1H OCEAN|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol='ocean_proximity', outputCol='ocean_proximity_index')
indexer_model = indexer.fit(train_data)
train_data = indexer_model.transform(train_data)
train_data.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|ocean_proximity_index|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+
# |  -124.35|   40.54|              52.0|     1820.0|         300.0|     806.0|     270.0|       3.0147|           94600.0|     NEAR OCEAN|                  2.0|
# |   -124.3|    41.8|              19.0|     2672.0|         552.0|    1298.0|     478.0|       1.9797|           85800.0|     NEAR OCEAN|                  2.0|
# |  -124.27|   40.69|              36.0|     2349.0|         528.0|    1194.0|     465.0|       2.5179|           79000.0|     NEAR OCEAN|                  2.0|
# |  -124.26|   40.58|              52.0|     2217.0|         394.0|     907.0|     369.0|       2.3571|          111400.0|     NEAR OCEAN|                  2.0|
# |  -124.25|   40.28|              32.0|     1430.0|         419.0|     434.0|     187.0|       1.9417|           76100.0|     NEAR OCEAN|                  2.0|
# |  -124.23|   40.81|              52.0|     1112.0|         209.0|     544.0|     172.0|       3.3462|           50800.0|     NEAR OCEAN|                  2.0|
# |  -124.22|   41.73|              28.0|     3003.0|         699.0|    1530.0|     653.0|       1.7038|           78300.0|     NEAR OCEAN|                  2.0|
# |  -124.21|   40.75|              32.0|     1218.0|         331.0|     620.0|     268.0|       1.6528|           58100.0|     NEAR OCEAN|                  2.0|
# |  -124.21|   41.75|              20.0|     3810.0|         787.0|    1993.0|     721.0|       2.0074|           66900.0|     NEAR OCEAN|                  2.0|
# |  -124.21|   41.77|              17.0|     3461.0|         722.0|    1947.0|     647.0|       2.5795|           68400.0|     NEAR OCEAN|                  2.0|
# |  -124.19|   40.77|              30.0|     2975.0|         634.0|    1367.0|     583.0|        2.442|           69000.0|     NEAR OCEAN|                  2.0|
# |  -124.19|   40.78|              37.0|     1371.0|         319.0|     640.0|     260.0|       1.8242|           70000.0|     NEAR OCEAN|                  2.0|
# |  -124.19|   41.78|              15.0|     3140.0|         714.0|    1645.0|     640.0|       1.6654|           74600.0|     NEAR OCEAN|                  2.0|
# |  -124.18|   40.62|              35.0|      952.0|         178.0|     480.0|     179.0|       3.0536|          107000.0|     NEAR OCEAN|                  2.0|
# |  -124.18|   40.78|              33.0|     1076.0|         222.0|     656.0|     236.0|       2.5096|           72200.0|     NEAR OCEAN|                  2.0|
# |  -124.18|   40.78|              37.0|     1453.0|         293.0|     867.0|     310.0|       2.5536|           70200.0|     NEAR OCEAN|                  2.0|
# |  -124.18|   40.79|              39.0|     1836.0|         352.0|     883.0|     337.0|        1.745|           70500.0|     NEAR OCEAN|                  2.0|
# |  -124.18|   40.79|              40.0|     1398.0|         311.0|     788.0|     279.0|       1.4668|           64600.0|     NEAR OCEAN|                  2.0|
# |  -124.17|   40.74|              17.0|     2026.0|         338.0|     873.0|     313.0|       4.0357|          128900.0|     NEAR OCEAN|                  2.0|
# |  -124.17|   40.75|              13.0|     2171.0|         339.0|     951.0|     353.0|       4.8516|          116100.0|     NEAR OCEAN|                  2.0|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+
# only showing top 20 rows

# %%
train_data.select('ocean_proximity', 'ocean_proximity_index').distinct().show()
# Out:
# +---------------+---------------------+
# |ocean_proximity|ocean_proximity_index|
# +---------------+---------------------+
# |     NEAR OCEAN|                  2.0|
# |         INLAND|                  1.0|
# |       NEAR BAY|                  3.0|
# |         ISLAND|                  4.0|
# |      <1H OCEAN|                  0.0|
# +---------------+---------------------+

# %%
from pyspark.ml.feature import OneHotEncoder

encoder = OneHotEncoder(inputCol='ocean_proximity_index', outputCol='ocean_proximity_vec', dropLast=False)
encoder_model = encoder.fit(train_data)
train_data = encoder_model.transform(train_data)
train_data.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|ocean_proximity_index|ocean_proximity_vec|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+
# |  -124.35|   40.54|              52.0|     1820.0|         300.0|     806.0|     270.0|       3.0147|           94600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |   -124.3|    41.8|              19.0|     2672.0|         552.0|    1298.0|     478.0|       1.9797|           85800.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.27|   40.69|              36.0|     2349.0|         528.0|    1194.0|     465.0|       2.5179|           79000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.26|   40.58|              52.0|     2217.0|         394.0|     907.0|     369.0|       2.3571|          111400.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.25|   40.28|              32.0|     1430.0|         419.0|     434.0|     187.0|       1.9417|           76100.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.23|   40.81|              52.0|     1112.0|         209.0|     544.0|     172.0|       3.3462|           50800.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.22|   41.73|              28.0|     3003.0|         699.0|    1530.0|     653.0|       1.7038|           78300.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.21|   40.75|              32.0|     1218.0|         331.0|     620.0|     268.0|       1.6528|           58100.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.21|   41.75|              20.0|     3810.0|         787.0|    1993.0|     721.0|       2.0074|           66900.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.21|   41.77|              17.0|     3461.0|         722.0|    1947.0|     647.0|       2.5795|           68400.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.19|   40.77|              30.0|     2975.0|         634.0|    1367.0|     583.0|        2.442|           69000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.19|   40.78|              37.0|     1371.0|         319.0|     640.0|     260.0|       1.8242|           70000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.19|   41.78|              15.0|     3140.0|         714.0|    1645.0|     640.0|       1.6654|           74600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.18|   40.62|              35.0|      952.0|         178.0|     480.0|     179.0|       3.0536|          107000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.18|   40.78|              33.0|     1076.0|         222.0|     656.0|     236.0|       2.5096|           72200.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.18|   40.78|              37.0|     1453.0|         293.0|     867.0|     310.0|       2.5536|           70200.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.18|   40.79|              39.0|     1836.0|         352.0|     883.0|     337.0|        1.745|           70500.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.18|   40.79|              40.0|     1398.0|         311.0|     788.0|     279.0|       1.4668|           64600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.17|   40.74|              17.0|     2026.0|         338.0|     873.0|     313.0|       4.0357|          128900.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# |  -124.17|   40.75|              13.0|     2171.0|         339.0|     951.0|     353.0|       4.8516|          116100.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+
# only showing top 20 rows

# %%
train_data.select('ocean_proximity', 'ocean_proximity_index', 'ocean_proximity_vec').distinct().show()
# Out:
# +---------------+---------------------+-------------------+
# |ocean_proximity|ocean_proximity_index|ocean_proximity_vec|
# +---------------+---------------------+-------------------+
# |      <1H OCEAN|                  0.0|      (5,[0],[1.0])|
# |         ISLAND|                  4.0|      (5,[4],[1.0])|
# |         INLAND|                  1.0|      (5,[1],[1.0])|
# |       NEAR BAY|                  3.0|      (5,[3],[1.0])|
# |     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
# +---------------+---------------------+-------------------+

# %%
from pyspark.ml.feature import VectorAssembler

feature_columns = ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'ocean_proximity_vec']
assembler = VectorAssembler(inputCols=feature_columns, outputCol='unscaled_features')

train_data = assembler.transform(train_data)
train_data.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+--------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|ocean_proximity_index|ocean_proximity_vec|   unscaled_features|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+--------------------+
# |  -124.35|   40.54|              52.0|     1820.0|         300.0|     806.0|     270.0|       3.0147|           94600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[52.0,1820.0,300....|
# |   -124.3|    41.8|              19.0|     2672.0|         552.0|    1298.0|     478.0|       1.9797|           85800.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|
.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[32.0,1430.0,419....|[0.26704704068029...|
# |  -124.23|   40.81|              52.0|     1112.0|         209.0|     544.0|     172.0|       3.3462|           50800.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[52.0,1112.0,209....|[1.85210106716407...|
# |  -124.22|   41.73|              28.0|     3003.0|         699.0|    1530.0|     653.0|       1.7038|           78300.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[28.0,3003.0,699....|[-0.0499637646164...|
# |  -124.21|   40.75|              32.0|     1218.0|         331.0|     620.0|     268.0|       1.6528|           58100.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[32.0,1218.0,331....|[0.26704704068029...|
# |  -124.21|   41.75|              20.0|     3810.0|         787.0|    1993.0|     721.0|       2.0074|           66900.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[20.0,3810.0,787....|[-0.6839853752099...|
# |  -124.21|   41.77|              17.0|     3461.0|         722.0|    1947.0|     647.0|       2.5795|           68400.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[17.0,3461.0,722....|[-0.9217434791825...|
# |  -124.19|   40.77|              30.0|     2975.0|         634.0|    1367.0|     583.0|        2.442|           69000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[30.0,2975.0,634....|[0.10854163803191...|
# |  -124.19|   40.78|              37.0|     1371.0|         319.0|     640.0|     260.0|       1.8242|           70000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[37.0,1371.0,319....|[0.66331054730124...|
# |  -124.19|   41.78|              15.0|     3140.0|         714.0|    1645.0|     640.0|       1.6654|           74600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[15.0,3140.0,714....|[-1.0802488818309...|
# |  -124.18|   40.62|              35.0|      952.0|         178.0|     480.0|     179.0|       3.0536|          107000.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[35.0,952.0,178.0...|[0.50480514465286...|
# |  -124.18|   40.78|              33.0|     1076.0|         222.0|     656.0|     236.0|       2.5096|           72200.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[33.0,1076.0,222....|[0.34629974200448...|
# |  -124.18|   40.78|              37.0|     1453.0|         293.0|     867.0|     310.0|       2.5536|           70200.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[37.0,1453.0,293....|[0.66331054730124...|
# |  -124.18|   40.79|              39.0|     1836.0|         352.0|     883.0|     337.0|        1.745|           70500.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[39.0,1836.0,352....|[0.82181594994961...|
# |  -124.18|   40.79|              40.0|     1398.0|         311.0|     788.0|     279.0|       1.4668|           64600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[40.0,1398.0,311....|[0.90106865127380...|
# |  -124.17|   40.74|              17.0|     2026.0|         338.0|     873.0|     313.0|       4.0357|          128900.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[17.0,2026.0,338....|[-0.9217434791825...|
# |  -124.17|   40.75|              13.0|     2171.0|         339.0|     951.0|     353.0|       4.8516|          116100.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[13.0,2171.0,339....|[-1.2387542844792...|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol='features', labelCol='median_house_value')
model = lr.fit(transformed_train_data)
# Out:
# 26/06/16 15:06:29 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/06/16 15:06:29 WARN Instrumentation: [3892d7ce] regParam is zero, which might cause numerical instability and overfitting.
# 26/06/16 15:06:29 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/06/16 15:06:30 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# 26/06/16 15:06:30 WARN Instrumentation: [3892d7ce] Cholesky solver failed due to singular covariance matrix. Retrying with Quasi-Newton solver.

# %%
test_data = indexer_model.transform(test_data)
test_data = encoder_model.transform(test_data)
test_data = assembler.transform(test_data)
test_data = scaler_model.transform(test_data)
test_data.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+--------------------+--------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|ocean_proximity|ocean_proximity_index|ocean_proximity_vec|   unscaled_features|            features|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+---------------+---------------------+-------------------+--------------------+--------------------+
# |   -124.3|   41.84|              17.0|     2677.0|         531.0|    1244.0|     456.0|       3.0313|          103600.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[17.0,2677.0,531....|[-0.9217434791825...|
# |  -124.23|   40.54|              52.0|     2694.0|         453.0|    1152.0|     435.0|       3.0806|          106700.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|[52.0,2694.0,453....|[1.85210106716407...|
# |  -124.23|   41.75|              11.0|     3159.0|         616.0|    1343.0|     479.0|       2.4805|           73200.0|     NEAR OCEAN|                  2.0|      (5,[2],[1.0])|